# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrsenjiii/pandas_repository/blob/main/pandas_datetime_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %%
# d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
# df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# <ipython-input-3-de28a6a5a135>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')

# %%
d_parser = lambda x : pd.datetime.strptime(x , '%Y-%m-%d %I-%p')
df = pd.read_csv('sample_data/ETH_1h.csv' , parse_dates = ['Date'] , date_parser=d_parser)
# df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-118-e5277614e5c3>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x : pd.datetime.strptime(x , '%Y-%m-%d %I-%p')

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
# filter = (df['Date'] >  datetime.strptime('2020-05-04' , '%Y-%m-%d'))
# filter=(df['Date'] > pd.to_datetime('2019-02-04'))
# filter=(df['Date'] > '2019-02-04')
# filter=(df['Date'] > datetime.strptime('2019-02-04' , '%Y-%m-%d'))
filter
df.loc[filter]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 9687 2019-02-04 05:00:00  ETHUSD  106.01  106.05  105.61  105.70   178169.95
# 9688 2019-02-04 04:00:00  ETHUSD  105.96  106.35  105.90  106.01   217258.22
# 9689 2019-02-04 03:00:00  ETHUSD  105.59  106.10  105.59  105.96   133220.27
# 9690 2019-02-04 02:00:00  ETHUSD  105.70  105.78  105.53  105.59    98507.53
# 9691 2019-02-04 01:00:00  ETHUSD  105.95  105.95  105.60  105.70   207194.48
#
# [9692 rows x 7 columns]

# %%
df.set_index('Date' , inplace=True)
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df['High'].resample('M').sum()
# Out:
# Date
# 2017-07-31    163104.32
# 2017-08-31    223261.50
# 2017-09-30    216807.03
# 2017-10-31    228309.03
# 2017-11-30    257721.48
# 2017-12-31    473581.62
# 2018-01-31    815673.33
# 2018-02-28    591854.52
# 2018-03-31    472156.35
# 2018-04-30    373950.63
# 2018-05-31    506653.45
# 2018-06-30    376355.69
# 2018-07-31    345068.30
# 2018-08-31    241776.32
# 2018-09-30    164617.61
# 2018-10-31    155045.40
# 2018-11-30    121989.71
# 2018-12-31     80599.00
# 2019-01-31     95051.71
# 2019-02-28     84297.32
# 2019-03-31    101061.44
# 2019-04-30    119413.88
# 2019-05-31    163443.60
# 2019-06-30    198374.82
# 2019-07-31    186284.53
# 2019-08-31    149296.73
# 2019-09-30    133998.50
# 2019-10-31    133307.68
# 2019-11-30    125160.72
# 2019-12-31    102584.59
# 2020-01-31    115978.25
# 2020-02-29    166893.99
# 2020-03-31     65232.18
# Freq: M, Name: High, dtype: float64

# %%
df.loc['2018-01':'2018-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2018-02-28 23:00:00  ETHUSD  858.01  858.50  848.21  849.99  3984596.21
# 2018-02-28 22:00:00  ETHUSD  867.64  867.64  858.00  858.01  2331400.93
# 2018-02-28 21:00:00  ETHUSD  869.62  873.00  866.05  867.64  1598750.30
# 2018-02-28 20:00:00  ETHUSD  867.68  872.90  867.61  869.62  2967534.77
# 2018-02-28 19:00:00  ETHUSD  865.86  867.90  865.30  867.68   950462.68
# ...                     ...     ...     ...     ...     ...         ...
# 2018-01-01 04:00:00  ETHUSD  739.70  748.07  733.02  747.90  3180304.69
# 2018-01-01 03:00:00  ETHUSD  730.01  739.70  728.66  739.70  3461348.11
# 2018-01-01 02:00:00  ETHUSD  730.02  730.50  727.14  730.01  2950627.37
# 2018-01-01 01:00:00  ETHUSD  734.59  735.10  730.01  730.02  1886624.01
# 2018-01-01 00:00:00  ETHUSD  741.27  741.27  733.69  734.59  2697546.48
#
# [1416 rows x 6 columns]

# %%
df.loc['2018-01-01']['High'].mean()
# Out:
# 749.9775

# %%
import pandas as pd

# Sample DataFrame with datetime index
date_rng = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
data = {'value': range(len(date_rng))}
df = pd.DataFrame(data, index=date_rng)
df
# Out:
#             value
# 2023-01-01      0
# 2023-01-02      1
# 2023-01-03      2
# 2023-01-04      3
# 2023-01-05      4
# ...           ...
# 2023-12-27    360
# 2023-12-28    361
# 2023-12-29    362
# 2023-12-30    363
# 2023-12-31    364
#
# [365 rows x 1 columns]

# %%
# Resample to monthly data and sum the values
monthly_data = df.resample('M').sum()
monthly_data
# Out:
#             value
# 2023-01-31    465
# 2023-02-28   1246
# 2023-03-31   2294
# 2023-04-30   3135
# 2023-05-31   4185
# 2023-06-30   4965
# 2023-07-31   6076
# 2023-08-31   7037
# 2023-09-30   7725
# 2023-10-31   8928
# 2023-11-30   9555
# 2023-12-31  10819
